# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fs = 1024
t = np.arange(0, 1.0, 1.0 / fs)
features = [100,200,300]
intervals = [np.array([tt for tt in t]),
             np.array([tt if (0.6 < tt < 0.8) else 0 for tt in t]),
             np.array([tt if (0.2 < tt < 0.3) else 0 for tt in t]),
            ]
data = np.zeros(shape = (len(t),))
for i in range(len(features)):
    data += np.sin(2 * np.pi * features[i] * intervals[i])
plt.rcParams["figure.figsize"] = (15, 6)
plt.figure()
plt.plot(t,data)
plt.title("raw data")
plt.xlabel("time")
plt.ylabel("amplitude")
# Out:
# Text(0, 0.5, 'amplitude')

# %%
f = np.linspace(-fs / 2, fs / 2, len(data))
spectrum = np.abs(np.fft.fftshift(np.fft.fft(data)))
plt.rcParams["figure.figsize"] = (15, 6)
plt.figure()
plt.plot(f,spectrum)
plt.ylabel('energy')
plt.xlabel('frequency')
plt.title('spectrum')
plt.xticks([100 * i for i in range(-5,6)])
# Out:
# ([<matplotlib.axis.XTick at 0x2422aab12e0>,
#   <matplotlib.axis.XTick at 0x2422aab12b0>,
#   <matplotlib.axis.XTick at 0x2422aaa8eb0>,
#   <matplotlib.axis.XTick at 0x2422aad0e50>,
#   <matplotlib.axis.XTick at 0x2422aadc3a0>,
#   <matplotlib.axis.XTick at 0x2422aadc8b0>,
#   <matplotlib.axis.XTick at 0x2422aadcdc0>,
#   <matplotlib.axis.XTick at 0x2422aae3310>,
#   <matplotlib.axis.XTick at 0x2422aae3820>,
#   <matplotlib.axis.XTick at 0x2422aae3d30>,
#   <matplotlib.axis.XTick at 0x2422aae9280>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
