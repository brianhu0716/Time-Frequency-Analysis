# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib import cm
fs = 11240.
t = 10
time = np.arange(fs*t) / fs
frequency = 1000.
mysignal = np.sin(2.0 * np.pi * frequency * time)

nperseg = 2**14
noverlap = 2**13
f, t, Sxx = signal.spectrogram(mysignal, fs, nperseg=nperseg,noverlap=noverlap)

# %%
print(f)
print(Sxx)
# Out:
# [0.00000000e+00 6.86035156e-01 1.37207031e+00 ... 5.61862793e+03
#  5.61931396e+03 5.62000000e+03]
# [[4.92587730e-08 1.97815694e-08 8.69717465e-09 ... 4.82922925e-08
#   2.77047550e-09 2.94453774e-08]
#  [1.85405110e-09 7.44525457e-10 3.27373060e-10 ... 1.81764918e-09
#   1.04264019e-10 1.10831698e-09]
#  [1.44851054e-09 5.81679714e-10 2.55762471e-10 ... 1.42007527e-09
#   8.14606102e-11 8.65888456e-10]
#  ...
#  [7.90129234e-23 7.55055841e-23 5.79866915e-23 ... 8.47157218e-23
#   6.39919612e-23 6.56784544e-23]
#  [1.65577016e-22 1.43269565e-22 3.23228947e-23 ... 2.01582720e-22
#   7.05177309e-23 8.10699944e-23]
#  [1.04745455e-22 8.76866461e-23 2.78042444e-24 ... 1.32224486e-22
#   3.20992310e-23 3.98754657e-23]]

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_surface(f[:, None], t[None, :], 10.0*np.log10(Sxx), cmap=cm.coolwarm)
plt.show()
